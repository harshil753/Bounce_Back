# %%
import pandas as pd
import numpy as np
import winsound

# %%
time = pd.read_csv("26 weeks after 2.csv")
lows = pd.read_csv("low points 2.csv")

# %%
time = time.sort_index(ascending=False)
time
# Out:
#         Unnamed: 0 Ticker      Date   Open  Close     Volume
# 117597      117597   GNRC  20100219  13.40  13.23    1295200
# 117596      117596   GNRC  20100226  13.28  13.43     601400
# 117595      117595   GNRC  20100305  13.50  13.10     329900
# 117594      117594   GNRC  20100312  13.13  14.15     414200
# 117593      117593   GNRC  20100319  14.00  15.40    1114000
# 117592      117592   GNRC  20100326  15.24  14.75     639900
# 117591      117591   GNRC  20100401  13.51  14.30    2336900
# 117590      117590   GNRC  20100409  14.42  15.31     396600
# 117589      117589   GNRC  20100416  15.35  15.29     609700
# 117588      117588   GNRC  20100423  15.27  15.35     329600
# 117587      117587   GNRC  20100430  15.29  15.09     415100
# 117586      117586   GNRC  20100507  15.09  13.52     535600
# 117585      117585   GNRC  20100514  13.75  13.48     908600
# 117584      117584   GNRC  20100219  13.40  13.23    1295200
# ...

# %%
lows = lows.sort_index(ascending=False)
lows.head()
# Out:
#       Unnamed: 0  Close      Date  Open Ticker   Volume
# 4521        4521  10.99  20100528  13.5   GNRC   875400
# 4520        4520  15.32  20110211  13.5   GNRC   649900
# 4519        4519  17.25  20110603  13.5   GNRC   433400
# 4518        4518  16.52  20110819  13.5   GNRC   540500
# 4517        4517  38.85  20141010  13.5   GNRC  3633876

# %%
limit = 0 
ticker = ""
lowest = 0
num_weeks
for index, row in lows.iterrows():
    droptick = row["Ticker"]
    dropvalue = row["Close"]
    dropdate = row["Date"]
    rebound = dropvalue*1.25
    for index, line in time.iterrows():
        if(limit<26):
            if(line["Close"]>=rebound):
            else:
                num_weeks = num_weeks+1
        elif(limit=26):
            limit = 0
            ticker = line["Ticker"]
            lowest = line["Close"]
        limit = limit +1
# Out:
#         Unnamed: 0 Ticker      Date   Open  Close   Volume
# 117597      117597   GNRC  20100219  13.40  13.23  1295200
# 117596      117596   GNRC  20100226  13.28  13.43   601400
# 117595      117595   GNRC  20100305  13.50  13.10   329900
# 117594      117594   GNRC  20100312  13.13  14.15   414200
# 117593      117593   GNRC  20100319  14.00  15.40  1114000
# 117592      117592   GNRC  20100326  15.24  14.75   639900
# 117591      117591   GNRC  20100401  13.51  14.30  2336900
# 117590      117590   GNRC  20100409  14.42  15.31   396600
# 117589      117589   GNRC  20100416  15.35  15.29   609700
# 117588      117588   GNRC  20100423  15.27  15.35   329600
# 117587      117587   GNRC  20100430  15.29  15.09   415100
# 117586      117586   GNRC  20100507  15.09  13.52   535600
# 117585      117585   GNRC  20100514  13.75  13.48   908600
# 117584      117584   GNRC  20100219  13.40  13.23  1295200
# 117583      117583   GNRC  20100226  13.28  13.43   601400
# ...
