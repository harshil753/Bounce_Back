# %%
import pandas as pd
import winsound
import numpy as np

# %%
post_df = pd.read_csv("26 weeks after 2.csv")

# %%
pricedrop = pd.read_csv("")

# %%
post_df
# Out:
#         Unnamed: 0 Ticker      Date   Open  Close     Volume
# 0                0     PG  20081003  68.15  71.02  109008400
# 1                1     PG  20080926  70.01  68.84   74116100
# 2                2     PG  20080919  72.34  70.36  123239600
# 3                3     PG  20080912  71.33  73.15   81690200
# 4                4     PG  20080905  70.35  70.78   45565900
# 5                5     PG  20080829  71.33  69.77   43910500
# 6                6     PG  20080822  71.32  71.61   57415900
# 7                7     PG  20080815  69.62  71.60   62982400
# 8                8     PG  20080808  65.12  69.63   72124100
# 9                9     PG  20080801  64.39  64.95   67959000
# 10              10     PG  20080725  63.93  64.46   56352900
# 11              11     PG  20080718  63.93  63.67   91135400
# 12              12     PG  20080711  63.81  63.45   92006800
# 13              13     PG  20080703  60.69  63.67   64464900
# ...

# %%
lows = []
lowest = 0
for index, row in post_df.iterrows():
    if(lowest == 0):
        ticker = row["Ticker"]
        lowest = row["Close"]
    if(ticker == row["Ticker"]):
