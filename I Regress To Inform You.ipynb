# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv("the final countdown 2.csv")
df.drop("Unnamed: 0", axis=1, inplace=True)
df
# Out:
#      Ticker  lowest price     close      date      open      volume    Market Cap  num of weeks  bounceback score
# 0      GNRC       10.9900   13.1200  20100611   12.5300      315400    3213853674             2                 3
# 1      GNRC       15.3200   18.6000  20110225   17.2000      595000    3213853674             2                 3
# 2      GNRC       17.2500   20.4200  20110722   19.7400      404300    3213853674             7                 2
# 3      GNRC       16.5200   20.3100  20110826   16.9300      711500    3213853674             1                 4
# 4      GNRC       38.8500   45.3400  20141031   44.5200     4917911    3213853674             3                 3
# 5      GNRC       40.0000   49.0300  20171006   47.9000     2843620    3213853674           127                 0
# 6       KOP       34.7200   40.3500  20161125   38.1000      594891     995782128            70                 0
# ...

# %%
X = df[["close","volume","Market Cap"]]
y= df["num of weeks"].reshape(-1,1)

print(X.shape, y.shape)
# Out:
# (4204, 3) (4204, 1)
# C:\Users\harsh\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1235)

# %%
from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
# Out:
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
# Out:
# C:\Users\harsh\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# Create the model using the MLP Classifier
from sklearn.neural_network import MLPRegressor

model = MLPRegressor(hidden_layer_sizes=(30,20), max_iter=1000, random_state=1)

# %%
model.fit(X_train_scaled, y_train_scaled.ravel())
model
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(30, 20), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
training_score = model.score(X_train_scaled, y_train_scaled)
testing_score = model.score(X_test_scaled, y_test_scaled)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.025211009841513695
# Testing Score: 0.02783477785434041

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)

training_score = model.score(X_train,y_train)
testing_score = model.score(X_test, y_test)

print("m: ", model.coef_)
print("b: ", model.intercept_)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# m:  [[  3.70391561e-02  -5.56247434e-08   6.18060272e-11]]
# b:  [ 16.26665424]
# Training Score: 0.003915341886501222
# Testing Score: -0.0020883320415399087
